# %% [markdown]
# # Lanzamiento de dado
# ## Ian Julián Estrada Castro
#
# Este programa simula el lanzamiento de un dado 1000 veces. Almacena los números en un arreglo y muestra el histograma con las frecuencias de las veces que salio cada cara

# %% [markdown]
# ## Librerías

# %%
import random
import seaborn

# %% [markdown]
# ## Códigos

# %%
list = []
for i in range(1000):
    number = random.randint(1, 6)
    list.append(number)

# %% [markdown]
# ## Histograma
